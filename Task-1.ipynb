# %% [markdown]
# # Author : Mohan A
#
# ## GRIP @ The Sparks Foundation
# ### Task 1 : Prediction using Supervised Machine Learning
#
# By using Simple Linear regression we have to predict the percentage of marks that a student can score based on the number of hours they studied

# %%
import pandas as pd
import numpy as np  
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # **STEP 1** - Data Reading

# %%
src = r"https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
data = pd.read_csv(src)
print("Import Successful")

data.head(12)
# Out:
# Import Successful
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62

# %% [markdown]
# ## **Step 2** - Data Visualization

# %%
#Hours and Percentage score is plotted in X and Y axis respectively
data.plot(x='Hours', y='Scores', style='x')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
data.shape
# Out:
# (25, 2)

# %% [markdown]
# ## **Step 3** - Data Preprocessing

# %%
#Splitting Input and Output
x = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86])

# %% [markdown]
# ## Step 4 - Model Training
# Splitting the data into training and testing sets, and training the algorithm.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0) 
regressor = LinearRegression()  
regressor.fit(x_train.reshape(-1,1), y_train) 

print("Training completed Successfully")
# Out:
# Training completed Successfully

# %% [markdown]
# ## **Step 5** - Plotting The Line

# %%
# Plotting the Best-fitting line
line = regressor.coef_ * x + regressor.intercept_


plt.scatter(x, y)
plt.plot(x, line,color='red');
plt.show()

# %% [markdown]
# ## **Step 6** - Predictions on Test Data

# %%
print(x_test)

y_pred = regressor.predict(x_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %% [markdown]
# ## **Step 7** - Actual  vs Prediction

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred}) 
df.head()
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
print("Training Score:",regressor.score(x_train,y_train))
print("Test Score:",regressor.score(x_test,y_test))
# Out:
# Training Score: 0.9515510725211552
# Test Score: 0.9454906892105354

# %%
df.plot(kind='bar',figsize=(5,5))
plt.grid(which='major', linewidth='0.5', color='red')
plt.grid(which='minor', linewidth='0.5', color='blue')
plt.show()

# %% [markdown]
# ## **Step 8** - Testing With Given Data

# %%
hrs = 9.25
test = np.array([hrs])
test = test.reshape(-1, 1)
pred = regressor.predict(test)
print("No of Hours = {}".format(hrs))
print("Predicted Score = {}".format(pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# ## Step 8 - Final Evaluation

# %%
from sklearn import metrics  
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test, y_pred)) 
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R-2:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
# Root Mean Squared Error: 4.647447612100373
# Mean Squared Error: 21.598769307217456
# R-2: 0.9454906892105354

# %% [markdown]
# # Conclusion
